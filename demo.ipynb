# %% [markdown]
# # 🤖 Topic T4: Subscription Manager AI Agent
# ### Built with LangChain & OpenAI API
#
# **Core Requirements:**
# - **Two Tools**: `add_subscription(name, cost)` and `get_monthly_total()` (decorated with LangChain `@tool`)
# - **Memory**: Remembers all active subscriptions across turns
# - **Agentic**: When over budget, decides which subscriptions to suggest cancelling to get back under
# - **Group of 3 Add-on**: Renewal-date reminders and a yearly-cost view

# %%
import importlib
import tools
import agent
importlib.reload(tools)
importlib.reload(agent)
from agent import SubscriptionAgent

# Clear memory for a fresh agent session
tools.memory.clear()
agent_instance = SubscriptionAgent()
print("Subscription Agent initialized with LangChain tools and memory!")
# Out:
# Subscription Agent initialized with LangChain tools and memory!

# %% [markdown]
# ## 🎯 Goal 1: Adding Subscriptions Within Budget (with Renewal Dates & Yearly-Cost View)

# %%
agent_instance.run("Add Netflix for $15 renewing on the 5th, and Spotify for $10 renewing on the 20th. My monthly budget is $40.")
# Out:
# =================================================================
# [USER]: Add Netflix for $15 renewing on the 5th, and Spotify for $10 renewing on the 20th. My monthly budget is $40.
# =================================================================
#  -> [TOOL CALL] add_subscription({'name': 'Netflix', 'cost': 15, 'renewal_date': '5th'}) => Added 'Netflix' at $15.00/month (Renewal Date: 5th).
#  -> [TOOL CALL] add_subscription({'name': 'Spotify', 'cost': 10, 'renewal_date': '20th'}) => Added 'Spotify' at $10.00/month (Renewal Date: 20th).
#  -> [TOOL CALL] get_monthly_total({}) => Active Subscriptions: {'Netflix': {'cost': 15.0, 'renewal_date': '5th'}, 'Spotify': {'cost': 10.0, 'renewal_date': '20th'}} | Monthly Total: $25.00 | Yearly Total: $300.00
#
# [AGENT RESPONSE]:
# **Subscription Summary**
#
# | Service | Monthly Cost | Renewal Date |
# |---------|--------------|--------------|
# | Netflix | $15.00 | 5th of each month |
# | Spotify | $10.00 | 20th of each month |
#
# **Totals**
#
# - **Monthly Total:** **$25.00**
# - **Yearly Total:** **$300.00**
#
# **Budget Check**
#
# Your current monthly spend ($25.00) is well below your budget of $40.00, so no cancellations are needed at this time.
#
# **Renewal Reminders**
#
# - **Netflix:** 5th of every month
# - **Spotify:** 20th of every month
#
# Feel free to let me know if youd like to add or remove any subscriptions!
# '**Subscription Summary**\n\n| Service | Monthly Cost | Renewal Date |\n|---------|--------------|--------------|\n| Netflix | $15.00 | 5th of each month |\n| Spotify | $10.00 | 20th of each month |\n\n**Totals**\n\n- **Monthly Total:** **$25.00**  \n- **Yearly Total:** **$300.00**\n\n**Budget Check**\n\nYour current monthly spend ($25.00) is well below your budget of $40.00, so no cancellations are needed at this time.\n\n**Renewal Reminders**\n\n- **Netflix:** 5th of every month  \n- **Spotify:** 20th of every month  \n\nFeel free to let me know if you’d like to add or remove any subscriptions!'

# %% [markdown]
# ## 🎯 Goal 2: Exceeding Budget -> Agentic Cancellation Recommendation
# The agent adds Gym Membership ($50), observes the total ($75 > $50), and decides what to cancel to get back under budget.

# %%
agent_instance.run("Add Gym Membership for $50 renewing on the 1st. My budget is $50. Check if I'm over budget and suggest what to cancel to get back under.")
# Out:
# =================================================================
# [USER]: Add Gym Membership for $50 renewing on the 1st. My budget is $50. Check if I'm over budget and suggest what to cancel to get back under.
# =================================================================
#  -> [TOOL CALL] add_subscription({'name': 'Gym Membership', 'cost': 50, 'renewal_date': '1st'}) => Added 'Gym Membership' at $50.00/month (Renewal Date: 1st).
#  -> [TOOL CALL] get_monthly_total({}) => Active Subscriptions: {'Netflix': {'cost': 15.0, 'renewal_date': '5th'}, 'Spotify': {'cost': 10.0, 'renewal_date': '20th'}, 'Gym Membership': {'cost': 50.0, 'renewal_date': '1st'}} | Monthly Total: $75.00 | Yearly Total: $900.00
#
# [AGENT RESPONSE]:
# **Subscription Summary**
#
# | Service          | Monthly Cost | Renewal Date |
# |------------------|--------------|--------------|
# | Netflix          | $15.00 | 5th of each month |
# | Spotify          | $10.00 | 20th of each month |
# | Gym Membership   | $50.00 | 1st of each month |
#
# **Totals**
#
# - **Monthly Total:** **$75.00**
# - **Yearly Total:** **$900.00**
#
# **Budget Check**
#
# Your budget is **$50.00** per month, so youre **$25.00 over budget**.
#
# **Suggested Cancellation(s) to Get Back Under Budget**
#
# | Subscription | Monthly Cost | Reason |
# |---------------|--------------|--------|
# | Netflix | $15.00 | Reduces spend to $60.00 |
# | Spotify | $10.00 | Reduces spend to $50.00
# '**Subscription Summary**\n\n| Service          | Monthly Cost | Renewal Date |\n|------------------|--------------|--------------|\n| Netflix          | $15.00 | 5th of each month |\n| Spotify          | $10.00 | 20th of each month |\n| Gym Membership   | $50.00 | 1st of each month |\n\n**Totals**\n\n- **Monthly Total:** **$75.00**  \n- **Yearly Total:** **$900.00**\n\n**Budget Check**\n\nYour budget is **$50.00** per month, so you’re **$25.00 over budget**.\n\n**Suggested Cancellation(s) to Get Back Under Budget**\n\n| Subscription | Monthly Cost | Reason |\n|---------------|--------------|--------|\n| Netflix | $15.00 | Reduces spend to $60.00 |\n| Spotify | $10.00 | Reduces spend to $50.00'

# %% [markdown]
# ## 🎯 Goal 3: Multi-turn Memory Retention + Renewal Reminders + Yearly View

# %%
agent_instance.run("Also add Disney+ for $14 renewing on the 12th. Show my total, yearly cost, renewal reminders, and best cancellation plan for my $50 budget.")
# Out:
# =================================================================
# [USER]: Also add Disney+ for $14 renewing on the 12th. Show my total, yearly cost, renewal reminders, and best cancellation plan for my $50 budget.
# =================================================================
#
# [AGENT RESPONSE]:
# ''
