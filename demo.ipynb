# %% [markdown]
# # 🤖 Topic T4: Subscription Manager AI Agent
# ### Powered by `meta/llama-3.3-70b-instruct` on NVIDIA NIM API
#
# **Core Requirements:**
# - **Two Tools**: `add_subscription(name, cost)` and `get_monthly_total()`
# - **Memory**: Remembers all active subscriptions across turns
# - **Agentic**: When over a budget, decides which subscriptions to suggest cancelling to get back under
# - **Group of 3 Add-on**: Renewal-date reminders and a yearly-cost view

# %%
import importlib
import tools
import agent
importlib.reload(tools)
importlib.reload(agent)
from agent import SubscriptionAgent

# Clear memory for a fresh agent session
tools.memory.clear()
agent_instance = SubscriptionAgent()
print("Subscription Agent initialized with updated tools and memory!")
# Out:
# Subscription Agent initialized with updated tools and memory!

# %% [markdown]
# ## 🎯 Goal 1: Adding Subscriptions Within Budget (with Renewal Dates & Yearly-Cost View)

# %%
agent_instance.run("Add Netflix for $15 renewing on the 5th, and Spotify for $10 renewing on the 20th. My monthly budget is $40.")
# Out:
# =================================================================
# [USER]: Add Netflix for $15 renewing on the 5th, and Spotify for $10 renewing on the 20th. My monthly budget is $40.
# =================================================================
#  -> [TOOL CALL] add_subscription({'cost': 15.0, 'name': 'Netflix', 'renewal_date': '5'}) => Added 'Netflix' at $15.00/month (Renewal Date: 5).
#  -> [TOOL CALL] add_subscription({'name': 'Spotify', 'cost': 10.0, 'renewal_date': '20'}) => Added 'Spotify' at $10.00/month (Renewal Date: 20).
#  -> [TOOL CALL] get_monthly_total({}) => Active Subscriptions: {'Netflix': {'cost': 15.0, 'renewal_date': '5'}, 'Spotify': {'cost': 10.0, 'renewal_date': '20'}} | Monthly Total: $25.00 | Yearly Total: $300.00
#
# [AGENT RESPONSE]:
# Since the monthly total ($25) is less than the budget ($40), there is no need to cancel any subscriptions.
# 'Since the monthly total ($25) is less than the budget ($40), there is no need to cancel any subscriptions.'

# %% [markdown]
# ## 🎯 Goal 2: Exceeding Budget -> Agentic Cancellation Recommendation
# The agent adds Gym Membership ($50), observes the total ($75 > $50), and decides what to cancel to get back under budget.

# %%
agent_instance.run("Add Gym Membership for $50 renewing on the 1st. My budget is $50. Check if I'm over budget and suggest what to cancel to get back under.")
# Out:
# =================================================================
# [USER]: Add Gym Membership for $50 renewing on the 1st. My budget is $50. Check if I'm over budget and suggest what to cancel to get back under.
# =================================================================
#  -> [TOOL CALL] add_subscription({'renewal_date': '1', 'name': 'Gym Membership', 'cost': 50.0}) => Added 'Gym Membership' at $50.00/month (Renewal Date: 1).
#  -> [TOOL CALL] get_monthly_total({}) => Active Subscriptions: {'Netflix': {'cost': 15.0, 'renewal_date': '5'}, 'Spotify': {'cost': 10.0, 'renewal_date': '20'}, 'Gym Membership': {'cost': 50.0, 'renewal_date': '1'}} | Monthly Total: $75.00 | Yearly Total: $900.00
#
# [AGENT RESPONSE]:
# Since the monthly total ($75) exceeds the budget ($50), you should consider canceling one or more subscriptions to get back under budget. In this case, you could cancel the Gym Membership and Netflix subscriptions to bring the monthly total down to $10 (Spotify's cost).
# "Since the monthly total ($75) exceeds the budget ($50), you should consider canceling one or more subscriptions to get back under budget. In this case, you could cancel the Gym Membership and Netflix subscriptions to bring the monthly total down to $10 (Spotify's cost)."

# %% [markdown]
# ## 🎯 Goal 3: Multi-turn Memory Retention + Renewal Reminders + Yearly View

# %%
agent_instance.run("Also add Disney+ for $14 renewing on the 12th. Show my total, yearly cost, renewal reminders, and best cancellation plan for my $50 budget.")
# Out:
# =================================================================
# [USER]: Also add Disney+ for $14 renewing on the 12th. Show my total, yearly cost, renewal reminders, and best cancellation plan for my $50 budget.
# =================================================================
#  -> [TOOL CALL] add_subscription({'name': 'Disney+', 'renewal_date': '12', 'cost': 14.0}) => Added 'Disney+' at $14.00/month (Renewal Date: 12).
#  -> [TOOL CALL] get_monthly_total({}) => Active Subscriptions: {'Netflix': {'cost': 15.0, 'renewal_date': '5'}, 'Spotify': {'cost': 10.0, 'renewal_date': '20'}, 'Gym Membership': {'cost': 50.0, 'renewal_date': '1'}, 'Disney+': {'cost': 14.0, 'renewal_date': '12'}} | Monthly Total: $89.00 | Yearly Total: $1068.00
#
# [AGENT RESPONSE]:
# Since the monthly total ($89) exceeds the budget ($50), you should consider canceling one or more subscriptions to get back under budget. In this case, you could cancel the Gym Membership and Netflix subscriptions to bring the monthly total down to $24 (Spotify and Disney+ costs).
# 'Since the monthly total ($89) exceeds the budget ($50), you should consider canceling one or more subscriptions to get back under budget. In this case, you could cancel the Gym Membership and Netflix subscriptions to bring the monthly total down to $24 (Spotify and Disney+ costs).'
